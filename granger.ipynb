# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Granger Causality

# %%
t = np.arange(1, 101)
x = t/10 + np.random.normal(size=len(t))
y = x + np.random.normal(size=len(t))

# %%
plt.plot(t, x)
plt.plot(t, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# x=>yの因果
data = np.array([[x],[y]]).reshape(100, 2)

from statsmodels.tsa.stattools import grangercausalitytests
maxlag = 1
results = grangercausalitytests(data, maxlag) # x: 2darray (data数, 2), x[:,0] => x[:,1]への因果を検定 
p_value = results[1]
print(p_value)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=16.6887 , p=0.0001  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=17.2102 , p=0.0000  , df=1
# likelihood ratio test: chi2=15.8678 , p=0.0001  , df=1
# parameter F test:         F=16.6887 , p=0.0001  , df_denom=96, df_num=1
# ({'ssr_ftest': (16.688688806521732, 9.132399404459741e-05, 96.0, 1), 'ssr_chi2test': (17.210210331725534, 3.346330009454014e-05, 1), 'lrtest': (15.867805043622639, 6.792443861507646e-05, 1), 'params_ftest': (16.68868880652171, 9.132399404459804e-05, 96.0, 1.0)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x113b72af0>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x121fc3a30>, array([[0., 1., 0.]])])

# %%
# y=>xの因果
data = np.array([[y],[x]]).reshape(100, 2)

from statsmodels.tsa.stattools import grangercausalitytests
maxlag = 1
results = grangercausalitytests(data, maxlag) # x: 2darray (data数, 2), x[:,0] => x[:,1]への因果を検定 
p_value = results[1]
print(p_value)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=18.8788 , p=0.0000  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=19.4688 , p=0.0000  , df=1
# likelihood ratio test: chi2=17.7734 , p=0.0000  , df=1
# parameter F test:         F=18.8788 , p=0.0000  , df_denom=96, df_num=1
# ({'ssr_ftest': (18.878807539350255, 3.4601953337822926e-05, 96.0, 1), 'ssr_chi2test': (19.468770274954952, 1.0225796802953473e-05, 1), 'lrtest': (17.773423838656413, 2.488348609133556e-05, 1), 'params_ftest': (18.878807539350245, 3.4601953337822926e-05, 96.0, 1.0)}, [<statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x113b72a30>, <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x113b72fa0>, array([[0., 1., 0.]])])
